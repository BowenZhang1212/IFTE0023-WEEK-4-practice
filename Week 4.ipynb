# %%
pip install meteostat
# Out:
# Collecting meteostat
#   Obtaining dependency information for meteostat from https://files.pythonhosted.org/packages/23/93/0d277de2b38238072b850e33fbd94e230951f2e5d7ac140ae221a05215b0/meteostat-1.6.7-py3-none-any.whl.metadata
#   Downloading meteostat-1.6.7-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: pandas>=1.1 in c:\users\bowen\anaconda3\lib\site-packages (from meteostat) (2.0.3)
# Requirement already satisfied: pytz in c:\users\bowen\anaconda3\lib\site-packages (from meteostat) (2023.3.post1)
# Requirement already satisfied: numpy in c:\users\bowen\anaconda3\lib\site-packages (from meteostat) (1.24.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\bowen\anaconda3\lib\site-packages (from pandas>=1.1->meteostat) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\bowen\anaconda3\lib\site-packages (from pandas>=1.1->meteostat) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\bowen\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.1->meteostat) (1.16.0)
# Downloading meteostat-1.6.7-py3-none-any.whl (31 kB)
# Installing collected packages: meteostat
# Successfully installed meteostat-1.6.7
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
from meteostat import Point, Daily

# %%
start = datetime(2016, 10, 31)
end = datetime(2023, 10, 31)

# %%
location = Point(51.5072, 0.1276, 11)

# %%
data = Daily(location, start, end)
data = data.fetch()

# %%
data.plot(y=['tavg'])
plt.show()

# %%
data.head()
# Out:
#             tavg  tmin  tmax  prcp  snow  wdir  wspd  wpgt  pres  tsun
# time
# 2016-10-31  12.8  10.0  17.0   NaN   NaN   NaN   6.6   NaN   NaN   NaN
# 2016-11-01  10.5   8.0  13.0   NaN   NaN   NaN   8.0   NaN   NaN   NaN
# 2016-11-02   8.1   6.0  11.0   NaN   NaN   NaN   9.6   NaN   NaN   NaN
# 2016-11-03   7.8   4.0  11.0   NaN   NaN   NaN   9.9   NaN   NaN   NaN
# 2016-11-04   9.5   8.0  12.0   NaN   NaN   NaN   9.0   NaN   NaN   NaN

# %%
import pandas as pd
import matplotlib.ticker as ticker
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from scipy.stats import norm,normaltest,probplot
from scipy import optimize
from matplotlib import style
from statistics import pstdev
import pylab
